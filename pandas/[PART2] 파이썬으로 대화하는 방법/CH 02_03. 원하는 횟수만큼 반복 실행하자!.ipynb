# %% [markdown]
# ### 이번 실습에서는 다음 내용들을 배웁니다.
#
#
# - 정해진 횟수만큼 명령을 수행하고 싶을 때 사용하는 for문에 대해 배웁니다.
#
#
# - 파이썬에서 for를 사용하는 방법에 대해 배웁니다.

# %% [markdown]
# ### 2. `for` statement

# %% [markdown]
# - while문은 조건이 만족하는 동안 반복을 수행했지만, for문은 지정 횟수동안 반복을 수행한다.
# > 여기서 지정된 횟수라는 것은 반복 대상의 크기가 된다.
#
#
# - 보통 iteratable object(반복 가능한 객체)를 대상으로 수행되며, 연속형 데이터 타입 변수들이 여기에 해당된다.
# > List, Tuple, string, ...
#
#
# - for 변수 in 리스트(튜플, 문자열, iterator):
#       <statement1>
#       <statement2>
#       <statement3>
#
# - 리스트(나 반복가능한 변수들)의 모든 원소를 (자동으로 끝까지) 반복한다.

# %%
# 원소가 1, 2, 3인 리스트의 원소를 하나하나 출력하는 반복문을 만든다.
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# #### 6개의 커피 음료가 담긴 리스트가 있다. 카페에 있는 모든 음료를 출력해보자!

# %%
coffees = ['아메리카노', '카페라떼', '카페모카', '바닐라라떼', '핸드드립', '콜드브루']

for i in coffees:
    print(i)
# Out:
# 아메리카노
# 카페라떼
# 카페모카
# 바닐라라떼
# 핸드드립
# 콜드브루

# %% [markdown]
# #### for문의 단짝 range() 함수

# %% [markdown]
# - for문은 특정 횟수동안 반복을 하기 때문에, 횟수를 자동으로 만들어주는 기능이 있으면 좋다.
#
# - 파이썬에서 기본적으로 제공하는 range 함수는 특정 숫자 범위내의 값들을 자동으로 생성해주는 함수이다.
#
#
# e.g. range(1, 5)는 1, 2, 3, 4를 차례대로 생성해준다. (5는 범위에서 제외된다. 즉, 마지막 숫자는 제외된다. 1 <= x < 5)

# %%
# range 함수를 이용해 1부터 4까지 출력하는 프로그램을 작성해보자. for문을 이용해서!
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# #### 6개의 커피 음료와 음료의 가격이 담긴 리스트가 있다. 가지고 있는 돈이 5,000원일 때 먹을 수 있는 모든 음료를 찾아보자!

# %%
coffees = ['아메리카노', '카페라떼', '카페모카', '바닐라라떼', '핸드드립', '콜드브루']
prices = [4100, 4600, 4600, 5100, 6000, 5000]

#1. index
for i in range(6):
    if prices[i] <= 5000:
        print(coffees[i])

print()

#2. enumerate
for i, price in enumerate(prices):
    if price <= 5000:
        print(coffees[i])

print()

#3
for coffee, price in zip(coffees, prices):
    if price <= 5000:
        print(coffee)
# Out:
# 아메리카노
# 카페라떼
# 카페모카
# 콜드브루
#
# 아메리카노
# 카페라떼
# 카페모카
# 콜드브루
#
# 아메리카노
# 카페라떼
# 카페모카
# 콜드브루

# %% [markdown]
# #### RE : 6개의 커피 음료와 음료의 가격이 담긴 리스트가 있다. 오늘은 할인 행사를 하여 모든 음료가 500원 할인 되었다!
#
# #### 가지고 있는 돈이 5,000원일 때 먹을 수 있는 모든 음료를 찾아보자!

# %%
coffees = ['아메리카노', '카페라떼', '카페모카', '바닐라라떼', '핸드드립', '콜드브루']
prices = [4100, 4600, 4600, 5100, 6000, 5000]

# %% [markdown]
# #### 전설의 구구단 구현. nested loop를 연습해보자!

# %%
# nested loop를 이용하여 구구단을 구현합시다. 

for i in range(1,10):
    print("-"*10)
    for j in range(1,10):
        print(f"{i} X {j} = {i*j}")
# Out:
# ----------
# 1 X 1 = 1
# 1 X 2 = 2
# 1 X 3 = 3
# 1 X 4 = 4
# 1 X 5 = 5
# 1 X 6 = 6
# 1 X 7 = 7
# 1 X 8 = 8
# 1 X 9 = 9
# ----------
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# ----------
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# ----------
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# ----------
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# ----------
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# ----------
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# ----------
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
# ----------
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81

# %% [markdown]
# ### 연습문제. 단어 갯수 구하기
#
# * 다음과 같은 영어기사 5개가 있다.
# * 철수는 다음 뉴스기사들의 어떤 단어가 얼마나 나왔는지 궁금해졌다.
# * 뉴스기사에서 등장하는 모든 단어마다 개수를 세어보자!
#
#
# **[HINT]**
#
# 1. 각 문장을 단어로 나누려면 어떻게 해야할지 고민해보세요.
#
#
# 2. 각 단어를 저장할 data type을 고민해보세요. 어떤 구조가 좋을까요?
#
#
# 3. 반복문을 통해서 단어 하나하나의 count를 계산합니다.

# %%
#아래 5개의 변수들은 각각 하나의 문서를 의미합니다.
news1 = "earn champion products ch approves stock split champion products inc said its board of directors approved a two for one stock split of its common shares for shareholders of record as of april the company also said its board voted to recommend to shareholders at the annual meeting april an increase in the authorized capital stock from five mln to mln shares reuter"
news2 = "acq computer terminal systems cpml completes sale computer terminal systems inc said it has completed the sale of shares of its common stock and warrants to acquire an additional one mln shares to sedio n v of lugano switzerland for dlrs the company said the warrants are exercisable for five years at a purchase price of dlrs per share computer terminal said sedio also has the right to buy additional shares and increase its total holdings up to pct of the computer terminal s outstanding common stock under certain circumstances involving change of control at the company the company said if the conditions occur the warrants would be exercisable at a price equal to pct of its common stock s market price at the time not to exceed dlrs per share computer terminal also said it sold the technolgy rights to its dot matrix impact technology including any future improvements to woodco inc of houston tex for dlrs but it said it would continue to be the exclusive worldwide licensee of the technology for woodco the company said the moves were part of its reorganization plan and would help pay current operation costs and ensure product delivery computer terminal makes computer generated labels forms tags and ticket printers and terminals reuter"
news3 = "earn cobanco inc cbco year net shr cts vs dlrs net vs assets mln vs mln deposits mln vs mln loans mln vs mln note th qtr not available year includes extraordinary gain from tax carry forward of dlrs or five cts per shr reuter"
news4 = "earn am international inc am nd qtr jan oper shr loss two cts vs profit seven cts oper shr profit vs profit revs mln vs mln avg shrs mln vs mln six mths oper shr profit nil vs profit cts oper net profit vs profit revs mln vs mln avg shrs mln vs mln note per shr calculated after payment of preferred dividends results exclude credits of or four cts and or nine cts for qtr and six mths vs or six cts and or cts for prior periods from operating loss carryforwards reuter"
news5 = "earn brown forman inc bfd th qtr net shr one dlr vs cts net mln vs mln revs mln vs mln nine mths shr dlrs vs dlrs net mln vs mln revs billion vs mln reuter"

# %%
## 코드를 작성해보세요.

news1 = "earn champion products ch approves stock split champion products inc said its board of directors approved a two for one stock split of its common shares for shareholders of record as of april the company also said its board voted to recommend to shareholders at the annual meeting april an increase in the authorized capital stock from five mln to mln shares reuter"
news2 = "acq computer terminal systems cpml completes sale computer terminal systems inc said it has completed the sale of shares of its common stock and warrants to acquire an additional one mln shares to sedio n v of lugano switzerland for dlrs the company said the warrants are exercisable for five years at a purchase price of dlrs per share computer terminal said sedio also has the right to buy additional shares and increase its total holdings up to pct of the computer terminal s outstanding common stock under certain circumstances involving change of control at the company the company said if the conditions occur the warrants would be exercisable at a price equal to pct of its common stock s market price at the time not to exceed dlrs per share computer terminal also said it sold the technolgy rights to its dot matrix impact technology including any future improvements to woodco inc of houston tex for dlrs but it said it would continue to be the exclusive worldwide licensee of the technology for woodco the company said the moves were part of its reorganization plan and would help pay current operation costs and ensure product delivery computer terminal makes computer generated labels forms tags and ticket printers and terminals reuter"
news3 = "earn cobanco inc cbco year net shr cts vs dlrs net vs assets mln vs mln deposits mln vs mln loans mln vs mln note th qtr not available year includes extraordinary gain from tax carry forward of dlrs or five cts per shr reuter"
news4 = "earn am international inc am nd qtr jan oper shr loss two cts vs profit seven cts oper shr profit vs profit revs mln vs mln avg shrs mln vs mln six mths oper shr profit nil vs profit cts oper net profit vs profit revs mln vs mln avg shrs mln vs mln note per shr calculated after payment of preferred dividends results exclude credits of or four cts and or nine cts for qtr and six mths vs or six cts and or cts for prior periods from operating loss carryforwards reuter"
news5 = "earn brown forman inc bfd th qtr net shr one dlr vs cts net mln vs mln revs mln vs mln nine mths shr dlrs vs dlrs net mln vs mln revs billion vs mln reuter"

news1 = news1.split()
news2 = news2.split()
news3 = news3.split()
news4 = news4.split()
news5 = news5.split()

list_of_news = [news1, news2, news3, news4, news5]

count = 0

for news in list_of_news:
#     print(news)
    print("-"*8)
    for words in news:
        print(words, news.count(words))
        if words in news == words in news:
            count += 1
            print(words, news.count(words))
# Out:
# --------
# earn 1
# champion 2
# products 2
# ch 1
# approves 1
# stock 3
# split 2
# champion 2
# products 2
# inc 1
# said 2
# its 3
# board 2
# of 4
# directors 1
# approved 1
# a 1
# two 1
# for 2
# one 1
# stock 3
# split 2
# of 4
# its 3
# common 1
# shares 2
# for 2
# shareholders 2
# of 4
# record 1
# as 1
# of 4
# april 2
# the 3
# company 1
# also 1
# said 2
# its 3
# board 2
# voted 1
# to 3
# recommend 1
# to 3
# shareholders 2
# at 1
# the 3
# annual 1
# meeting 1
# april 2
# an 1
# increase 1
# in 1
# the 3
# authorized 1
# capital 1
# stock 3
# from 1
# five 1
# mln 2
# to 3
# mln 2
# shares 2
# reuter 1
# --------
# acq 1
# computer 7
# terminal 6
# systems 2
# cpml 1
# completes 1
# sale 2
# computer 7
# terminal 6
# systems 2
# inc 2
# said 7
# it 4
# has 2
# completed 1
# the 15
# sale 2
# of 10
# shares 3
# of 10
# its 5
# common 3
# stock 3
# and 6
# warrants 3
# to 9
# acquire 1
# an 1
# additional 2
# one 1
# mln 1
# shares 3
# to 9
# sedio 2
# n 1
# v 1
# of 10
# lugano 1
# switzerland 1
# for 4
# dlrs 4
# the 15
# company 4
# said 7
# the 15
# warrants 3
# are 1
# exercisable 2
# for 4
# five 1
# years 1
# at 4
# a 2
# purchase 1
# price 3
# of 10
# dlrs 4
# per 2
# share 2
# computer 7
# terminal 6
# said 7
# sedio 2
# also 2
# has 2
# the 15
# right 1
# to 9
# buy 1
# additional 2
# shares 3
# and 6
# increase 1
# its 5
# total 1
# holdings 1
# up 1
# to 9
# pct 2
# of 10
# the 15
# computer 7
# terminal 6
# s 2
# outstanding 1
# common 3
# stock 3
# under 1
# certain 1
# circumstances 1
# involving 1
# change 1
# of 10
# control 1
# at 4
# the 15
# company 4
# the 15
# company 4
# said 7
# if 1
# the 15
# conditions 1
# occur 1
# the 15
# warrants 3
# would 3
# be 2
# exercisable 2
# at 4
# a 2
# price 3
# equal 1
# to 9
# pct 2
# of 10
# its 5
# common 3
# stock 3
# s 2
# market 1
# price 3
# at 4
# the 15
# time 1
# not 1
# to 9
# exceed 1
# dlrs 4
# per 2
# share 2
# computer 7
# terminal 6
# also 2
# said 7
# it 4
# sold 1
# the 15
# technolgy 1
# rights 1
# to 9
# its 5
# dot 1
# matrix 1
# impact 1
# technology 2
# including 1
# any 1
# future 1
# improvements 1
# to 9
# woodco 2
# inc 2
# of 10
# houston 1
# tex 1
# for 4
# dlrs 4
# but 1
# it 4
# said 7
# it 4
# would 3
# continue 1
# to 9
# be 2
# the 15
# exclusive 1
# worldwide 1
# licensee 1
# of 10
# the 15
# technology 2
# for 4
# woodco 2
# the 15
# company 4
# said 7
# the 15
# moves 1
# were 1
# part 1
# of 10
# its 5
# reorganization 1
# plan 1
# and 6
# would 3
# help 1
# pay 1
# current 1
# operation 1
# costs 1
# and 6
# ensure 1
# product 1
# delivery 1
# computer 7
# terminal 6
# makes 1
# computer 7
# generated 1
# labels 1
# forms 1
# tags 1
# and 6
# ticket 1
# printers 1
# and 6
# terminals 1
# reuter 1
# --------
# earn 1
# cobanco 1
# inc 1
# cbco 1
# year 2
# net 2
# shr 2
# cts 2
# vs 5
# dlrs 2
# net 2
# vs 5
# assets 1
# mln 6
# vs 5
# mln 6
# deposits 1
# mln 6
# vs 5
# mln 6
# loans 1
# mln 6
# vs 5
# mln 6
# note 1
# th 1
# qtr 1
# not 1
# available 1
# year 2
# includes 1
# extraordinary 1
# gain 1
# from 1
# tax 1
# carry 1
# forward 1
# of 1
# dlrs 2
# or 1
# five 1
# cts 2
# per 1
# shr 2
# reuter 1
# --------
# earn 1
# am 2
# international 1
# inc 1
# am 2
# nd 1
# qtr 2
# jan 1
# oper 4
# shr 4
# loss 2
# two 1
# cts 7
# vs 9
# profit 7
# seven 1
# cts 7
# oper 4
# shr 4
# profit 7
# vs 9
# profit 7
# revs 2
# mln 8
# vs 9
# mln 8
# avg 2
# shrs 2
# mln 8
# vs 9
# mln 8
# six 3
# mths 2
# oper 4
# shr 4
# profit 7
# nil 1
# vs 9
# profit 7
# cts 7
# oper 4
# net 1
# profit 7
# vs 9
# profit 7
# revs 2
# mln 8
# vs 9
# mln 8
# avg 2
# shrs 2
# mln 8
# vs 9
# mln 8
# note 1
# per 1
# shr 4
# calculated 1
# after 1
# payment 1
# of 2
# preferred 1
# dividends 1
# results 1
# exclude 1
# credits 1
# of 2
# or 4
# four 1
# cts 7
# and 3
# or 4
# nine 1
# cts 7
# for 2
# qtr 2
# and 3
# six 3
# mths 2
# vs 9
# or 4
# six 3
# cts 7
# and 3
# or 4
# cts 7
# for 2
# prior 1
# periods 1
# from 1
# operating 1
# loss 2
# carryforwards 1
# reuter 1
# --------
# earn 1
# brown 1
# forman 1
# inc 1
# bfd 1
# th 1
# qtr 1
# net 3
# shr 2
# one 1
# dlr 1
# vs 6
# cts 1
# net 3
# mln 7
# vs 6
# mln 7
# revs 2
# mln 7
# vs 6
# mln 7
# nine 1
# mths 1
# shr 2
# dlrs 2
# vs 6
# dlrs 2
# net 3
# mln 7
# vs 6
# mln 7
# revs 2
# billion 1
# vs 6
# mln 7
# reuter 1

# %%
## 코드를 작성해보세요.

news1 = "earn champion products ch approves stock split champion products inc said its board of directors approved a two for one stock split of its common shares for shareholders of record as of april the company also said its board voted to recommend to shareholders at the annual meeting april an increase in the authorized capital stock from five mln to mln shares reuter"
news2 = "acq computer terminal systems cpml completes sale computer terminal systems inc said it has completed the sale of shares of its common stock and warrants to acquire an additional one mln shares to sedio n v of lugano switzerland for dlrs the company said the warrants are exercisable for five years at a purchase price of dlrs per share computer terminal said sedio also has the right to buy additional shares and increase its total holdings up to pct of the computer terminal s outstanding common stock under certain circumstances involving change of control at the company the company said if the conditions occur the warrants would be exercisable at a price equal to pct of its common stock s market price at the time not to exceed dlrs per share computer terminal also said it sold the technolgy rights to its dot matrix impact technology including any future improvements to woodco inc of houston tex for dlrs but it said it would continue to be the exclusive worldwide licensee of the technology for woodco the company said the moves were part of its reorganization plan and would help pay current operation costs and ensure product delivery computer terminal makes computer generated labels forms tags and ticket printers and terminals reuter"
news3 = "earn cobanco inc cbco year net shr cts vs dlrs net vs assets mln vs mln deposits mln vs mln loans mln vs mln note th qtr not available year includes extraordinary gain from tax carry forward of dlrs or five cts per shr reuter"
news4 = "earn am international inc am nd qtr jan oper shr loss two cts vs profit seven cts oper shr profit vs profit revs mln vs mln avg shrs mln vs mln six mths oper shr profit nil vs profit cts oper net profit vs profit revs mln vs mln avg shrs mln vs mln note per shr calculated after payment of preferred dividends results exclude credits of or four cts and or nine cts for qtr and six mths vs or six cts and or cts for prior periods from operating loss carryforwards reuter"
news5 = "earn brown forman inc bfd th qtr net shr one dlr vs cts net mln vs mln revs mln vs mln nine mths shr dlrs vs dlrs net mln vs mln revs billion vs mln reuter"

news_combined = []
news_combined = (news1 + news2 + news3 + news4 + news5).split()



for words in news_combined:
    if news_combined.count(words) > 1:
        
    print(words, news_combined.count(words))

# news_combined = news_combined.split()

# for words in news_combined:
#     print(words, news_combined.count(words))

# for words in news_combined:
#     set_news = {words, news_combined.count(words)}
#     print(set_news)
    
#     print(set_list)
#     for i in words:
#         print("___________")
#         count = news_combined.count(words)
#         print(words, count)

    
# count = 0

# for news in list_of_news:
# #     print(news)
#     print("-"*8)
#     for words in news:
#         print(words, news.count(words))
#         if words in news == words in news:
#             count += 1
#             print(words, news.count(words))
# Out:
#   Cell In[147], line 16
#     news_combined.count(words) += 1
#     ^
# SyntaxError: 'function call' is an illegal expression for augmented assignment

# %%
n1 = news1.split()
n2 = news2.split()
n3 = news3.split()
n4 = news4.split()
n5 = news5.split()
n = n1 + n2 + n3 + n4 + n5
nd = {}
for i in n:
    nd[i] = 0
for i in n:
    nd[i] = nd[i] + 1
nd
# Out:
# {'earn': 4,
#  'champion': 2,
#  'products': 2,
#  'ch': 1,
#  'approves': 1,
#  'stock': 6,
#  'split': 2,
#  'inc': 6,
#  'said': 9,
#  'its': 8,
#  'board': 2,
#  'of': 17,
#  'directors': 1,
#  'approved': 1,
#  'a': 3,
#  'two': 2,
#  'for': 8,
#  'one': 3,
#  'common': 4,
#  'shares': 5,
#  'shareholders': 2,
#  'record': 1,
#  'as': 1,
#  'april': 2,
#  'the': 18,
#  'company': 5,
#  'also': 3,
#  'voted': 1,
#  'to': 12,
#  'recommend': 1,
#  'at': 5,
#  'annual': 1,
#  'meeting': 1,
#  'an': 2,
#  'increase': 2,
#  'in': 1,
#  'authorized': 1,
#  'capital': 1,
#  'from': 3,
#  'five': 3,
#  'mln': 24,
#  'reuter': 5,
#  'acq': 1,
#  'computer': 7,
#  'terminal': 6,
#  'systems': 2,
#  'cpml': 1,
#  'completes': 1,
#  'sale': 2,
#  'it': 4,
#  'has': 2,
#  'completed': 1,
#  'and': 9,
#  'warrants': 3,
#  'acquire': 1,
#  'additional': 2,
#  'sedio': 2,
#  'n': 1,
#  'v': 1,
#  'lugano': 1,
#  'switzerland': 1,
#  'dlrs': 8,
#  'are': 1,
#  'exercisable': 2,
#  'years': 1,
#  'purchase': 1,
#  'price': 3,
#  'per': 4,
#  'share': 2,
#  'right': 1,
#  'buy': 1,
#  'total': 1,
#  'holdings': 1,
#  'up': 1,
#  'pct': 2,
#  's': 2,
#  'outstanding': 1,
#  'under': 1,
#  'certain': 1,
#  'circumstances': 1,
#  'involving': 1,
#  'change': 1,
#  'control': 1,
#  'if': 1,
#  'conditions': 1,
#  'occur': 1,
#  'would': 3,
#  'be': 2,
#  'equal': 1,
#  'market': 1,
#  'time': 1,
#  'not': 2,
#  'exceed': 1,
#  'sold': 1,
#  'technolgy': 1,
#  'rights': 1,
#  'dot': 1,
#  'matrix': 1,
#  'impact': 1,
#  'technology': 2,
#  'including': 1,
#  'any': 1,
#  'future': 1,
#  'improvements': 1,
#  'woodco': 2,
#  'houston': 1,
#  'tex': 1,
#  'but': 1,
#  'continue': 1,
#  'exclusive': 1,
#  'worldwide': 1,
#  'licensee': 1,
#  'moves': 1,
#  'were': 1,
#  'part': 1,
#  'reorganization': 1,
#  'plan': 1,
#  'help': 1,
#  'pay': 1,
#  'current': 1,
#  'operation': 1,
#  'costs': 1,
#  'ensure': 1,
#  'product': 1,
#  'delivery': 1,
#  'makes': 1,
#  'generated': 1,
#  'labels': 1,
#  'forms': 1,
#  'tags': 1,
#  'ticket': 1,
#  'printers': 1,
#  'terminals': 1,
#  'cobanco': 1,
#  'cbco': 1,
#  'year': 2,
#  'net': 6,
#  'shr': 8,
#  'cts': 10,
#  'vs': 20,
#  'assets': 1,
#  'deposits': 1,
#  'loans': 1,
#  'note': 2,
#  'th': 2,
#  'qtr': 4,
#  'available': 1,
#  'includes': 1,
#  'extraordinary': 1,
#  'gain': 1,
#  'tax': 1,
#  'carry': 1,
#  'forward': 1,
#  'or': 5,
#  'am': 2,
#  'international': 1,
#  'nd': 1,
#  'jan': 1,
#  'oper': 4,
#  'loss': 2,
#  'profit': 7,
#  'seven': 1,
#  'revs': 4,
#  'avg': 2,
#  'shrs': 2,
#  'six': 3,
#  'mths': 3,
#  'nil': 1,
#  'calculated': 1,
#  'after': 1,
#  'payment': 1,
#  'preferred': 1,
#  'dividends': 1,
#  'results': 1,
#  'exclude': 1,
#  'credits': 1,
#  'four': 1,
#  'nine': 2,
#  'prior': 1,
#  'periods': 1,
#  'operating': 1,
#  'carryforwards': 1,
#  'brown': 1,
#  'forman': 1,
#  'bfd': 1,
#  'dlr': 1,
#  'billion': 1}

# %%
news1 = "earn champion products ch approves stock split champion products inc said its board of directors approved a two for one stock split of its common shares for shareholders of record as of april the company also said its board voted to recommend to shareholders at the annual meeting april an increase in the authorized capital stock from five mln to mln shares reuter"
news2 = "acq computer terminal systems cpml completes sale computer terminal systems inc said it has completed the sale of shares of its common stock and warrants to acquire an additional one mln shares to sedio n v of lugano switzerland for dlrs the company said the warrants are exercisable for five years at a purchase price of dlrs per share computer terminal said sedio also has the right to buy additional shares and increase its total holdings up to pct of the computer terminal s outstanding common stock under certain circumstances involving change of control at the company the company said if the conditions occur the warrants would be exercisable at a price equal to pct of its common stock s market price at the time not to exceed dlrs per share computer terminal also said it sold the technolgy rights to its dot matrix impact technology including any future improvements to woodco inc of houston tex for dlrs but it said it would continue to be the exclusive worldwide licensee of the technology for woodco the company said the moves were part of its reorganization plan and would help pay current operation costs and ensure product delivery computer terminal makes computer generated labels forms tags and ticket printers and terminals reuter"
news3 = "earn cobanco inc cbco year net shr cts vs dlrs net vs assets mln vs mln deposits mln vs mln loans mln vs mln note th qtr not available year includes extraordinary gain from tax carry forward of dlrs or five cts per shr reuter"
news4 = "earn am international inc am nd qtr jan oper shr loss two cts vs profit seven cts oper shr profit vs profit revs mln vs mln avg shrs mln vs mln six mths oper shr profit nil vs profit cts oper net profit vs profit revs mln vs mln avg shrs mln vs mln note per shr calculated after payment of preferred dividends results exclude credits of or four cts and or nine cts for qtr and six mths vs or six cts and or cts for prior periods from operating loss carryforwards reuter"
news5 = "earn brown forman inc bfd th qtr net shr one dlr vs cts net mln vs mln revs mln vs mln nine mths shr dlrs vs dlrs net mln vs mln revs billion vs mln reuter"

news1 = news1.split()
news2 = news2.split()
news3 = news3.split()
news4 = news4.split()
news5 = news5.split()

news_c = news1 + news2 + news3 + news4 + news5

words = set(news_c)

for word in words:
    print(word, news_c.count(word))


# answer = list(word_dict.keys, word_dict.values)
# print(word_dict.keys, word_dict.values)
# print(answer)


# for i in :
#     print(f"{i}, {i.count}")
# Out:
# increase 2
# costs 1
# meeting 1
# sedio 2
# makes 1
# outstanding 1
# control 1
# product 1
# one 3
# split 2
# licensee 1
# are 1
# dlr 1
# but 1
# moves 1
# approved 1
# stock 6
# credits 1
# available 1
# avg 2
# as 1
# were 1
# cbco 1
# shareholders 2
# s 2
# exercisable 2
# capital 1
# calculated 1
# assets 1
# dividends 1
# authorized 1
# inc 6
# carryforwards 1
# ticket 1
# deposits 1
# pay 1
# voted 1
# april 2
# forward 1
# reuter 5
# net 6
# rights 1
# completed 1
# prior 1
# seven 1
# its 8
# involving 1
# market 1
# part 1
# am 2
# for 8
# mths 3
# bfd 1
# future 1
# printers 1
# certain 1
# technology 2
# switzerland 1
# v 1
# matrix 1
# computer 7
# tax 1
# four 1
# revs 4
# also 3
# in 1
# shr 8
# champion 2
# exclusive 1
# acquire 1
# time 1
# systems 2
# delivery 1
# current 1
# five 3
# periods 1
# shares 5
# sale 2
# purchase 1
# gain 1
# or 5
# billion 1
# terminal 6
# ensure 1
# preferred 1
# loss 2
# vs 20
# be 2
# change 1
# including 1
# ch 1
# exceed 1
# terminals 1
# under 1
# lugano 1
# sold 1
# worldwide 1
# qtr 4
# houston 1
# technolgy 1
# products 2
# company 5
# per 4
# generated 1
# carry 1
# a 3
# dlrs 8
# has 2
# at 5
# right 1
# acq 1
# common 4
# pct 2
# approves 1
# to 12
# nd 1
# two 2
# board 2
# dot 1
# year 2
# continue 1
# tags 1
# additional 2
# occur 1
# directors 1
# operation 1
# cts 10
# six 3
# brown 1
# it 4
# reorganization 1
# results 1
# payment 1
# international 1
# recommend 1
# cpml 1
# cobanco 1
# not 2
# the 18
# exclude 1
# n 1
# record 1
# annual 1
# holdings 1
# note 2
# from 3
# woodco 2
# profit 7
# buy 1
# equal 1
# nil 1
# help 1
# labels 1
# plan 1
# shrs 2
# forman 1
# impact 1
# improvements 1
# an 2
# years 1
# operating 1
# price 3
# loans 1
# includes 1
# if 1
# up 1
# after 1
# completes 1
# share 2
# circumstances 1
# earn 4
# and 9
# total 1
# forms 1
# warrants 3
# of 17
# mln 24
# said 9
# tex 1
# any 1
# conditions 1
# th 2
# jan 1
# oper 4
# nine 2
# would 3
# extraordinary 1

# %%
news_c = "".join(news1 + " " + news2 + " " + news3 + " " + news4 + " " + news5)
print(news_c)
# Out:
# earn champion products ch approves stock split champion products inc said its board of directors approved a two for one stock split of its common shares for shareholders of record as of april the company also said its board voted to recommend to shareholders at the annual meeting april an increase in the authorized capital stock from five mln to mln shares reuter acq computer terminal systems cpml completes sale computer terminal systems inc said it has completed the sale of shares of its common stock and warrants to acquire an additional one mln shares to sedio n v of lugano switzerland for dlrs the company said the warrants are exercisable for five years at a purchase price of dlrs per share computer terminal said sedio also has the right to buy additional shares and increase its total holdings up to pct of the computer terminal s outstanding common stock under certain circumstances involving change of control at the company the company said if the conditions occur the warrants would be exercisable at a price equal to pct of its common stock s market price at the time not to exceed dlrs per share computer terminal also said it sold the technolgy rights to its dot matrix impact technology including any future improvements to woodco inc of houston tex for dlrs but it said it would continue to be the exclusive worldwide licensee of the technology for woodco the company said the moves were part of its reorganization plan and would help pay current operation costs and ensure product delivery computer terminal makes computer generated labels forms tags and ticket printers and terminals reuter earn cobanco inc cbco year net shr cts vs dlrs net vs assets mln vs mln deposits mln vs mln loans mln vs mln note th qtr not available year includes extraordinary gain from tax carry forward of dlrs or five cts per shr reuter earn am international inc am nd qtr jan oper shr loss two cts vs profit seven cts oper shr profit vs profit revs mln vs mln avg shrs mln vs mln six mths oper shr profit nil vs profit cts oper net profit vs profit revs mln vs mln avg shrs mln vs mln note per shr calculated after payment of preferred dividends results exclude credits of or four cts and or nine cts for qtr and six mths vs or six cts and or cts for prior periods from operating loss carryforwards reuter earn brown forman inc bfd th qtr net shr one dlr vs cts net mln vs mln revs mln vs mln nine mths shr dlrs vs dlrs net mln vs mln revs billion vs mln reuter

# %%
news_c = " ".join([news1, news2, news3, news4, news5])
print(news_c)
# Out:
# earn champion products ch approves stock split champion products inc said its board of directors approved a two for one stock split of its common shares for shareholders of record as of april the company also said its board voted to recommend to shareholders at the annual meeting april an increase in the authorized capital stock from five mln to mln shares reuter acq computer terminal systems cpml completes sale computer terminal systems inc said it has completed the sale of shares of its common stock and warrants to acquire an additional one mln shares to sedio n v of lugano switzerland for dlrs the company said the warrants are exercisable for five years at a purchase price of dlrs per share computer terminal said sedio also has the right to buy additional shares and increase its total holdings up to pct of the computer terminal s outstanding common stock under certain circumstances involving change of control at the company the company said if the conditions occur the warrants would be exercisable at a price equal to pct of its common stock s market price at the time not to exceed dlrs per share computer terminal also said it sold the technolgy rights to its dot matrix impact technology including any future improvements to woodco inc of houston tex for dlrs but it said it would continue to be the exclusive worldwide licensee of the technology for woodco the company said the moves were part of its reorganization plan and would help pay current operation costs and ensure product delivery computer terminal makes computer generated labels forms tags and ticket printers and terminals reuter earn cobanco inc cbco year net shr cts vs dlrs net vs assets mln vs mln deposits mln vs mln loans mln vs mln note th qtr not available year includes extraordinary gain from tax carry forward of dlrs or five cts per shr reuter earn am international inc am nd qtr jan oper shr loss two cts vs profit seven cts oper shr profit vs profit revs mln vs mln avg shrs mln vs mln six mths oper shr profit nil vs profit cts oper net profit vs profit revs mln vs mln avg shrs mln vs mln note per shr calculated after payment of preferred dividends results exclude credits of or four cts and or nine cts for qtr and six mths vs or six cts and or cts for prior periods from operating loss carryforwards reuter earn brown forman inc bfd th qtr net shr one dlr vs cts net mln vs mln revs mln vs mln nine mths shr dlrs vs dlrs net mln vs mln revs billion vs mln reuter

# %%
news_c = " ".join([news1, news2, news3, news4, news5])
dict([[word, news_c.count(word)] for word in set(news_c.split())])
# Out:
# {'increase': 2,
#  'costs': 1,
#  'meeting': 1,
#  'sedio': 2,
#  'makes': 1,
#  'outstanding': 1,
#  'control': 1,
#  'product': 3,
#  'one': 3,
#  'split': 2,
#  'licensee': 1,
#  'are': 10,
#  'dlr': 9,
#  'but': 1,
#  'moves': 1,
#  'approved': 1,
#  'stock': 6,
#  'credits': 1,
#  'available': 1,
#  'avg': 2,
#  'as': 7,
#  'were': 1,
#  'cbco': 1,
#  'shareholders': 2,
#  's': 173,
#  'exercisable': 2,
#  'capital': 1,
#  'calculated': 1,
#  'assets': 1,
#  'dividends': 1,
#  'authorized': 1,
#  'inc': 10,
#  'carryforwards': 1,
#  'ticket': 1,
#  'deposits': 1,
#  'pay': 2,
#  'voted': 1,
#  'april': 2,
#  'forward': 2,
#  'reuter': 5,
#  'net': 6,
#  'rights': 1,
#  'completed': 1,
#  'prior': 1,
#  'seven': 1,
#  'its': 10,
#  'involving': 1,
#  'market': 1,
#  'part': 1,
#  'am': 4,
#  'for': 12,
#  'mths': 3,
#  'bfd': 1,
#  'future': 1,
#  'printers': 1,
#  'certain': 1,
#  'technology': 2,
#  'switzerland': 1,
#  'v': 42,
#  'matrix': 1,
#  'computer': 7,
#  'tax': 1,
#  'four': 1,
#  'revs': 4,
#  'also': 3,
#  'in': 33,
#  'shr': 10,
#  'champion': 2,
#  'exclusive': 1,
#  'acquire': 1,
#  'time': 1,
#  'systems': 2,
#  'delivery': 1,
#  'current': 1,
#  'five': 3,
#  'periods': 1,
#  'shares': 5,
#  'sale': 2,
#  'purchase': 1,
#  'gain': 1,
#  'or': 24,
#  'billion': 1,
#  'terminal': 7,
#  'ensure': 1,
#  'preferred': 1,
#  'loss': 2,
#  'vs': 24,
#  'be': 3,
#  'change': 1,
#  'including': 1,
#  'ch': 8,
#  'exceed': 1,
#  'terminals': 1,
#  'under': 1,
#  'lugano': 1,
#  'sold': 1,
#  'worldwide': 1,
#  'qtr': 4,
#  'houston': 1,
#  'technolgy': 1,
#  'products': 2,
#  'company': 5,
#  'per': 11,
#  'generated': 1,
#  'carry': 2,
#  'a': 144,
#  'dlrs': 8,
#  'has': 3,
#  'at': 12,
#  'right': 2,
#  'acq': 2,
#  'common': 4,
#  'pct': 2,
#  'approves': 1,
#  'to': 21,
#  'nd': 16,
#  'two': 2,
#  'board': 2,
#  'dot': 1,
#  'year': 3,
#  'continue': 1,
#  'tags': 1,
#  'additional': 2,
#  'occur': 1,
#  'directors': 1,
#  'operation': 1,
#  'cts': 12,
#  'six': 3,
#  'brown': 1,
#  'it': 28,
#  'reorganization': 1,
#  'results': 1,
#  'payment': 1,
#  'international': 1,
#  'recommend': 1,
#  'cpml': 1,
#  'cobanco': 1,
#  'not': 4,
#  'the': 18,
#  'exclude': 1,
#  'n': 144,
#  'record': 1,
#  'annual': 1,
#  'holdings': 1,
#  'note': 2,
#  'from': 3,
#  'woodco': 2,
#  'profit': 7,
#  'buy': 1,
#  'equal': 1,
#  'nil': 1,
#  'help': 1,
#  'labels': 1,
#  'plan': 1,
#  'shrs': 2,
#  'forman': 1,
#  'impact': 1,
#  'improvements': 1,
#  'an': 32,
#  'years': 1,
#  'operating': 1,
#  'price': 3,
#  'loans': 1,
#  'includes': 1,
#  'if': 1,
#  'up': 1,
#  'after': 1,
#  'completes': 1,
#  'share': 9,
#  'circumstances': 1,
#  'earn': 4,
#  'and': 11,
#  'total': 1,
#  'forms': 1,
#  'warrants': 3,
#  'of': 24,
#  'mln': 24,
#  'said': 9,
#  'tex': 1,
#  'any': 6,
#  'conditions': 1,
#  'th': 24,
#  'jan': 1,
#  'oper': 6,
#  'nine': 2,
#  'would': 3,
#  'extraordinary': 1}

# %%
news_c = " ".join([news1, news2, news3, news4, news5]).split()
result = [[word, news_c.count(word)] for word in set(news_c)]

# %%
news1 = "earn champion products ch approves stock split champion products inc said its board of directors approved a two for one stock split of its common shares for shareholders of record as of april the company also said its board voted to recommend to shareholders at the annual meeting april an increase in the authorized capital stock from five mln to mln shares reuter"
news2 = "acq computer terminal systems cpml completes sale computer terminal systems inc said it has completed the sale of shares of its common stock and warrants to acquire an additional one mln shares to sedio n v of lugano switzerland for dlrs the company said the warrants are exercisable for five years at a purchase price of dlrs per share computer terminal said sedio also has the right to buy additional shares and increase its total holdings up to pct of the computer terminal s outstanding common stock under certain circumstances involving change of control at the company the company said if the conditions occur the warrants would be exercisable at a price equal to pct of its common stock s market price at the time not to exceed dlrs per share computer terminal also said it sold the technolgy rights to its dot matrix impact technology including any future improvements to woodco inc of houston tex for dlrs but it said it would continue to be the exclusive worldwide licensee of the technology for woodco the company said the moves were part of its reorganization plan and would help pay current operation costs and ensure product delivery computer terminal makes computer generated labels forms tags and ticket printers and terminals reuter"
news3 = "earn cobanco inc cbco year net shr cts vs dlrs net vs assets mln vs mln deposits mln vs mln loans mln vs mln note th qtr not available year includes extraordinary gain from tax carry forward of dlrs or five cts per shr reuter"
news4 = "earn am international inc am nd qtr jan oper shr loss two cts vs profit seven cts oper shr profit vs profit revs mln vs mln avg shrs mln vs mln six mths oper shr profit nil vs profit cts oper net profit vs profit revs mln vs mln avg shrs mln vs mln note per shr calculated after payment of preferred dividends results exclude credits of or four cts and or nine cts for qtr and six mths vs or six cts and or cts for prior periods from operating loss carryforwards reuter"
news5 = "earn brown forman inc bfd th qtr net shr one dlr vs cts net mln vs mln revs mln vs mln nine mths shr dlrs vs dlrs net mln vs mln revs billion vs mln reuter"

news_c = " ".join([news1, news2, news3, news4, news5]).split()
result = [[word, news_c.count(word)] for word in set(news_c)]

import pandas as pd

df = pd.DataFrame(result, columns=["word", "count"])

print(df.sort_values(by="count", ascending=False))
# Out:
#               word  count
# 176            mln     24
# 86              vs     20
# 138            the     18
# 175             of     17
# 114             to     12
# ..             ...    ...
# 72        delivery      1
# 73         current      1
# 75         periods      1
# 78        purchase      1
# 186  extraordinary      1
#
# [187 rows x 2 columns]

# %%
max_input = 5

input_cnt = 0
user_input_list = []
    
while input_cnt < max_input:
    user_input = input(f"please enter 5 different integers, {max_input - input_cnt} numbers remaining. \n")
    user_input_list.append(user_input)

    try:
        if user_input.isnumeric == True:
            continue
        input_cnt += 1
        
    except:
        print("please try again")


    
user_input_sorted = sorted(user_input_list)
print(f"max value = {user_input_sorted[-1]}, min value = {user_input_sorted[0]}")
# Out:
# please enter 5 different integers, 5 numbers remaining.
# 75
# please enter 5 different integers, 4 numbers remaining.
# 35
# please enter 5 different integers, 3 numbers remaining.
# 24
# please enter 5 different integers, 2 numbers remaining.
# 84
# please enter 5 different integers, 1 numbers remaining.
# 35
# max value = 84, min value = 24

# %%
from IPython.display import Image
from IPython.core.display import HTML 

try:
    # 최대 입력 횟수
    MAX_INPUT_COUNT = 5
    
    inputCount = 0
    userInputIntList = []

    while inputCount <= MAX_INPUT_COUNT :
        userInputValue = int(input("정수를 입력하세요."))
        userInputIntList.append(userInputValue)
        
        print(f"{userInputIntList} 중 최대값은 {max(userInputIntList)} 입니다.")

        inputCount += 1
except:
    print("미쳤습니까? 휴먼")
    display(Image(url= "https://mblogthumb-phinf.pstatic.net/MjAxODEyMDRfNzAg/MDAxNTQzOTMwMDU4MDI1.Nrg3F0XdrCYnS2vNBXUX5oyF5Dds7JPoYVT4BQIHWkgg.bVbUbzVLqfXFXgqTKs6pNcH8gpYtU2CrEMxgIExnDaQg.JPEG.dkgoggog21/ce9d6ee43b9fa3b8bc5828cf7d36e040cf8f1a66796e2a28b2552e67cf3d02ee55ca57531f25eb3dc9aba3d0e6f4b3ddff62e515120538e0a56ec7daaea1ee95d4ac5673b613.jpg?type=w2"))
# Out:
# 정수를 입력하세요.75
# [75] 중 최대값은 75 입니다.
# 정수를 입력하세요.asdf
# 미쳤습니까? 휴먼
# <img src="https://mblogthumb-phinf.pstatic.net/MjAxODEyMDRfNzAg/MDAxNTQzOTMwMDU4MDI1.Nrg3F0XdrCYnS2vNBXUX5oyF5Dds7JPoYVT4BQIHWkgg.bVbUbzVLqfXFXgqTKs6pNcH8gpYtU2CrEMxgIExnDaQg.JPEG.dkgoggog21/ce9d6ee43b9fa3b8bc5828cf7d36e040cf8f1a66796e2a28b2552e67cf3d02ee55ca57531f25eb3dc9aba3d0e6f4b3ddff62e515120538e0a56ec7daaea1ee95d4ac5673b613.jpg?type=w2"/>
