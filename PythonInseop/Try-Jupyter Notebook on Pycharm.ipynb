# %%
import selenium
import os
import chromedriver_autoinstaller
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

options = webdriver.ChromeOptions()

# options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
browser = webdriver.Chrome("chromedriver", options=options)

# browser = webdriver.Chrome()

# %%
app_name = input("댓글을 가져오고자 하는 앱 이름을 입력하세요 : ")

url = "https://play.google.com/store/search?q={}&c=apps&hl=ko"
search_url = url.format(app_name)
# print(search_url)

browser.get(search_url)
app_url = browser.find_element(By.CLASS_NAME, "Qfxief").get_attribute("href")
print(app_url)
browser.get(app_url)
# Out:
# 댓글을 가져오고자 하는 앱 이름을 입력하세요 : 배달의민족
# https://play.google.com/store/apps/details?id=com.sampleapp

# %%
print("클릭한다?")

XPATH_google = '//*[@id="yDmH0d"]/c-wiz[2]/div/div/div[1]/div[2]/div/div[1]/c-wiz[4]/section/header/div/div[2]/button'

click = browser.find_element(By.XPATH, XPATH_google)
click.click()

print("클릭됨? 됨!")
# Out:
# 클릭한다?
# 클릭됨? 됨!

# %% [markdown]
# def repeat_scroll(self, browser):
#     scroll_location = browser.execute_script("return document.body.scrollHeight")
#     while True:
#         browser.execute_script("window.scrollTo(0,document.body.scrollHeight")
#         time.sleep(2)
#         scroll_height = browser.execute_script("return document.body.scrollHeight")
#         if scroll_location == scroll_hieght:
#             break
#         else:
#             scroll_location = browser.execute_script("return document.body.scrollHeight")

# %% [markdown]
# modal = browser.find_element(By.CLASS_NAME, 'fysCi')
# class Repeat:
#     def repeat_scroll(self):
#         while True:
#             for review in reviews:
#                 num_review += 1
#                 if num_review == 2500:
#                     break
#                 user_names = review.find_element(By.CLASS_NAME, "X5PpBb").text
#                 ratings = review.find_element(By.CLASS_NAME, 'iXRFPc').get_attribute('aria-label')[6]
#                 comments = review.find_element(By.CLASS_NAME, "h3YV2d").text
#                 dates = review.find_element(By.CLASS_NAME, "bp9Aid").text
#                 data = {"user name" : user_names,
#                        "rating" : ratings,
#                        "content" : comments,
#                        "date" : dates}
#             data_list.append(data)
#
#             scroll_location = browser.execute_script("return document.body.scrollHeight")
#
#             browser.execute_script("window.scrollTo(0, document.body.scrollHeight")
#             time.sleep(2)
#             scroll_height = browser.execute_script("return document.body.scrollHeight")
#
#             if scroll_location == scroll_hieght:
#                 break
#             else:
#                 scroll_location = browser.execute_script("return document.body.scrollHeight")
#
# # for i in range(3):
# #     browser.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", modal)
# #     time.sleep(3)

# %%
# import pandas as pd

# %% [markdown]
# modal = browser.find_elements(By.CLASS_NAME, 'fysCi')
# def repeat_scroll(self):
#     while True:
#         scroll_location = browser.execute_script("return document.body.scrollHeight")
#
#         browser.execute_script("window.scrollTo(0, document.body.scrollHeight")
#         time.sleep(2)
#         scroll_height = browser.execute_script("return document.body.scrollHeight")
#
#         if scroll_location == scroll_height:
#             break
#         else:
#             scroll_location = browser.execute_script("return document.body.scrollHeight")

# %%
modal = browser.find_elements(By.CLASS_NAME, 'fysCi')

for i in range(3):
    browser.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", modal)
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# Cell In[6], line 4
#       1 modal = browser.find_elements(By.CLASS_NAME, 'fysCi')
#       3 for i in range(3):
# ----> 4     browser.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight)", modal)
#       5     time.sleep(3)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:500, in WebDriver.execute_script(self, script, *args)
#     497 converted_args = list(args)
#     498 command = Command.W3C_EXECUTE_SCRIPT
# --> 500 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
# ...

# %%
reviews = browser.find_elements(By.CLASS_NAME, "RHo1pe")
num_review = 0
data_list = []


while num_review < 2500:
    for review in reviews:
        num_review += 1
        if num_review == 250:
            break
        user_names = review.find_element(By.CLASS_NAME, "X5PpBb").text
        ratings = review.find_element(By.CLASS_NAME, 'iXRFPc').get_attribute('aria-label')[6]
        comments = review.find_element(By.CLASS_NAME, "h3YV2d").text
        dates = review.find_element(By.CLASS_NAME, "bp9Aid").text
        data = {"user name" : user_names,
               "rating" : ratings,
               "content" : comments,
               "date" : dates}
        data_list.append(data)
    if num_review == 2500:
        break

        
    
    #     while True:
#         scroll_location = browser.execute_script("return document.body.scrollHeight")
    
#         browser.execute_script("window.scrollTo(0, document.body.scrollHeight")
#         time.sleep(2)
#         scroll_height = browser.execute_script("return document.body.scrollHeight")
        
#         if scroll_location == scroll_height:
#             break
#         else:
#             scroll_location = browser.execute_script(return document.body.scrollHeight)


            

df = pd.DataFrame(data_list)
df.to_csv("./google_playstore.csv", encoding="utf-8-sig")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 14
#      12 ratings = review.find_element(By.CLASS_NAME, 'iXRFPc').get_attribute('aria-label')[6]
#      13 comments = review.find_element(By.CLASS_NAME, "h3YV2d").text
# ---> 14 dates = review.find_element(By.CLASS_NAME, "bp9Aid").text
#      15 data = {"user name" : user_names,
#      16        "rating" : ratings,
#      17        "content" : comments,
#      18        "date" : dates}
#      19 data_list.append(data)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# ...

# %% [markdown]
# reviews = browser.find_elements(By.CLASS_NAME, "RHo1pe")
# num_review = 0
# data_list = []
# Repeat.repeat_scroll
#
#
# df = pd.DataFrame(data_list)
# df.to_csv("./google_playstore.csv", encoding="utf-8-sig")

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
import time
import pandas as pd
from pandas import DataFrame


options = webdriver.ChromeOptions()

# options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
driver = webdriver.Chrome("chromedriver", options=options)

# # 여기서 부터 ---->
# service = Service("/usr/bin/chromedriver")

# options = Options()
# # options.add_argument("--headless")
# options.add_argument("--no-sandbox")


# driver = webdriver.Chrome(service=service, options=options)
# # 화면이 작아지면 보이는 것과 다르니 본인이 사용하는 해상도를 꼭 맞추세요!!
# driver.set_window_size(1120, 1150)
# # <---- 여기까지는 본인이 쓰던 데로 쓰세요

# 디비 피아 논문 인공지능 검색
driver.get("https://www.dbpia.co.kr/search/topSearch?searchOption=all&query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5#a")
time.sleep(1)

# 논문 링크 1~3페이지 수집용
paperUrlList = []

# -----------------------------------------------------------------
# 1 페이지 이동
driver.find_elements(By.CSS_SELECTOR, "#pageList > a")[0].click()
# 페이지 이동 후 화면처리가 존재하므로 딜레이 필요 안되면 초를 늘리세요.
time.sleep(1)
# 1페이지 수집
# class이름으로 논문 링크 객체 수집
paperList = driver.find_elements(By.CLASS_NAME, "thesis__link")

# 논문 링크 객체에서 URL 수집
for paper in paperList:
    paperUrlList.append(paper.get_attribute("href"))

# -----------------------------------------------------------------
# 2 페이지 이동
driver.find_elements(By.CSS_SELECTOR, "#pageList > a")[1].click()
# 페이지 이동 후 화면처리가 존재하므로 딜레이 필요 안되면 초를 늘리세요.
time.sleep(1)

# 2페이지 수집
# class이름으로 논문 링크 객체 수집
paperList = driver.find_elements(By.CLASS_NAME, "thesis__link")

# 논문 링크 객체에서 URL 수집
for paper in paperList:
    paperUrlList.append(paper.get_attribute("href"))

paging = driver.find_elements(By.CSS_SELECTOR, "#pageList > a")


# -----------------------------------------------------------------
# 3 페이지 이동
driver.find_elements(By.CSS_SELECTOR, "#pageList > a")[2].click()
# 페이지 이동 후 화면처리가 존재하므로 딜레이 필요 안되면 초를 늘리세요.
time.sleep(1)

# 3페이지 수집
# class이름으로 논문 링크 객체 수집
paperList = driver.find_elements(By.CLASS_NAME, "thesis__link")

# 논문 링크 객체에서 URL 수집
for paper in paperList:
    paperUrlList.append(paper.get_attribute("href"))

paging = driver.find_elements(By.CSS_SELECTOR, "#pageList > a")


# 논문 정보 저장용
paperInfoList = []

# 논문 링크 마다 데이터 수집
# [:3] 테스트를 위해 3개만 먼저 수행 다 도릴 때는 삭제
for paperUrl in paperUrlList[:3]:

    # 논문 접속
    driver.get(paperUrl)

    # 타이틀 가져오기
    # ID 가 존재하면 ID로 단일 선택
    title = driver.find_element(By.ID, "thesisTitle").text

    # 이용수 가져오기
    # ID가 존재하니 ID로 단일 선택
    useCount = driver.find_element(By.ID, "showUsageChartButton").text

    # 키워드 가져오기
    # class 이름만 존재. class로 가져올 때는 가급적 다건으로 가져오자 find_element*s*
    # 다건 중 첫번째 것만 추출
    keywordElements = driver.find_elements(By.CLASS_NAME, "abstractTxt");
    # 키워드가 찾아지지 않으면 빈값으로 되게
    keyword = ""
    # 키워드가 찾아지면 입력
    if len(keywordElements) > 0:
        keyword = keywordElements[0].text

    # 저자정보 가져오기
    # 저자는 여러명 일 수 있으므로 css selector를 이용해서 다건으로 가져오자 find_element*s*
    authorElements = driver.find_elements(By.CSS_SELECTOR, ".thesisDetail__author > .authorList > li")
    
    # 가져온 객체에서 텍스트 추출해서 배열로 만들기
    authorList = []
    for author in authorElements:
        authorList.append(author.text)
    
    # 나중에 한칸의 셀에 , 로 구분해서 넣기용
    authorStrList = ",".join(authorList)

    # 저자 나누기
    authorArray = ["", "", "", "", ""]

    # 실제 저자가 5명 미만인 경우 오류 방지용
    minLength = min([len(authorArray), len(authorList)])

    # 저자가 5명 넘어도 제한해서 널 수 있게
    for i in range(minLength):
        authorArray[i] = authorList[i]

    # 딕션으로 만들기
    paperInfo = {
        "title" : title
        , "useCount" : useCount
        , "keyword" : keyword
        , "authorList" : authorList
        , "authorStrList" : authorStrList
        , "author1" : authorArray[0]
        , "author2" : authorArray[1]
        , "author3" : authorArray[2]
        , "author4" : authorArray[3]
        , "author5" : authorArray[4]
    }

    paperInfoList.append(paperInfo)

    # 1개 가져오고 1초 쉬기
    time.sleep(1)

# pandasd용 데이터 프레임으로 전환
data_df = DataFrame(paperInfoList)
data_df
#CSV 변환
data_df.to_csv("파일이름.csv")
#엑셀 변환
data_df.to_excel("파일이름.xls")
